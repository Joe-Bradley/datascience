# %%
from pyecharts import options as opts
from pyecharts.charts import Map
import pandas as pd

# %%
def map_china(data) -> Map:
    c = (
        Map()
            .add(series_name="确诊病例", data_pair=data, maptype="china", zoom=1, center=[105, 38])
            .set_global_opts(
            title_opts=opts.TitleOpts(title="疫情地图"),
            visualmap_opts=opts.VisualMapOpts(max_=9999, is_piecewise=True,
                                              pieces=[{"max": 9, "min": 0, "label": "0-9", "color": "#FFE4E1"},
                                                      {"max": 99, "min": 10, "label": "10-99", "color": "#FF7F50"},
                                                      {"max": 499, "min": 100, "label": "100-499", "color": "#F08080"},
                                                      {"max": 999, "min": 500, "label": "500-999", "color": "#CD5C5C"},
                                                      {"max": 9999, "min": 1000, "label": ">=1000", "color": "#8B0000"}]
                                              )
        )
    )
    return c

# %%
data = [('湖北', 9074), ('浙江', 661), ('广东', 632), ('河南', 493), ('湖南', 463),
            ('安徽', 340), ('江西', 333), ('重庆', 275), ('江苏', 236), ('四川', 231),
            ('山东', 230), ('北京', 191), ('上海', 182), ('福建', 159), ('陕西', 116),
            ('广西', 111), ('云南', 105), ('河北', 104), ('黑龙江', 95), ('辽宁', 69),
            ('海南', 64), ('新疆', 21), ('内蒙古', 21), ('宁夏', 28), ('青海', 11), ('甘肃', 40), ('西藏', 1),
            ('贵州', 38), ('山西', 56), ('吉林', 23), ('台湾', 10), ('天津', 48), ('香港', 14), ('澳门', 8)]

# %%
d_map = map_china(data)
d_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="d8e8d14c4ff24f0e954d7efb54c68833" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_d8e8d14c4ff24f0e954d7efb54c68833 = echarts.init(
#                     document.getElementById('d8e8d14c4ff24f0e954d7efb54c68833'), 'white', {renderer: 'canvas'});
#                 var option_d8e8d14c4ff24f0e954d7efb54c68833 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u786e\u8bca\u75c5\u4f8b",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 9074
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 661
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 632
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 493
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 463
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 340
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 333
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 275
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 236
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 231
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 230
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 191
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 182
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 159
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 95
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 69
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 8
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "center": [
#                 105,
#                 38
#             ],
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca\u75c5\u4f8b"
#             ],
#             "selected": {
#                 "\u786e\u8bca\u75c5\u4f8b": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u75ab\u60c5\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 9999,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "max": 9,
#                 "min": 0,
#                 "label": "0-9",
#                 "color": "#FFE4E1"
#             },
#             {
#                 "max": 99,
#                 "min": 10,
#                 "label": "10-99",
#                 "color": "#FF7F50"
#             },
#             {
#                 "max": 499,
#                 "min": 100,
#                 "label": "100-499",
#                 "color": "#F08080"
#             },
#             {
#                 "max": 999,
#                 "min": 500,
#                 "label": "500-999",
#                 "color": "#CD5C5C"
#             },
#             {
#                 "max": 9999,
#                 "min": 1000,
#                 "label": ">=1000",
#                 "col
